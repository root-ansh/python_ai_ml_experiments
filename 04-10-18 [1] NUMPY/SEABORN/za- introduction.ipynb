# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as mplt

print(sns.__version__)
print(np.__version__)
print(pd.__version__)
# Out:
# 0.9.0
# 1.15.3
# 0.23.4

# %%
filename=r'C:\Users\anshs\00ANSH_PYTHON\0_DATASETS and LARGE FILES\menu.csv'
data =pd.read_csv(filename)
print(data.head())
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat          ...           \
# ...

# %%
print(data.head())
# Out:
#   emp_id           name location  age  home_at
# 0  emp11   Aakash Kumar    Patna   22    Noida
# 1  emp12    Naman Arora  Lucknow   18    Delhi
# 2  emp13     Vikas Jain   Bhopal   18  Gurgaon
# 3  emp14  Nirmal Mishra  Gurgaon   21  Gurgaon
# 4  emp15    Priya Singh  Gurgaon   25    Delhi

# %%
print(data.tail())
# Out:
#   emp_id               name   location  age    home_at
# 4  emp15        Priya Singh    Gurgaon   25      Delhi
# 5  cnt17  Rishab Srivastava     Mumbai   22      Noida
# 6  emp16      Pravita Singh     Kanpur   21      Delhi
# 7  tmp18        Naina Gupta    Sonipat   28  New Delhi
# 8  cnt19         Jai Tiwari  Hyderabad   24      Noida

# %%
print(data.describe())
# Out:
#              age
# count   9.000000
# mean   22.111111
# std     3.218868
# min    18.000000
# 25%    21.000000
# 50%    22.000000
# 75%    24.000000
# max    28.000000

# %%
data['spec_number'] = 0, -1.25, 1, 2, -1.75, 3.25, 0, 0,-2.25
print(data)
# Out:
#   emp_id               name   location  age    home_at  spec_number
# 0  emp11       Aakash Kumar      Patna   22      Noida         0.00
# 1  emp12        Naman Arora    Lucknow   18      Delhi        -1.25
# 2  emp13         Vikas Jain     Bhopal   18    Gurgaon         1.00
# 3  emp14      Nirmal Mishra    Gurgaon   21    Gurgaon         2.00
# 4  emp15        Priya Singh    Gurgaon   25      Delhi        -1.75
# 5  cnt17  Rishab Srivastava     Mumbai   22      Noida         3.25
# 6  emp16      Pravita Singh     Kanpur   21      Delhi         0.00
# 7  tmp18        Naina Gupta    Sonipat   28  New Delhi         0.00
# 8  cnt19         Jai Tiwari  Hyderabad   24      Noida        -2.25

# %%
print(data.describe())
# Out:
#              age  spec_number
# count   9.000000     9.000000
# mean   22.111111     0.111111
# std     3.218868     1.772671
# min    18.000000    -2.250000
# 25%    21.000000    -1.250000
# 50%    22.000000     0.000000
# 75%    24.000000     1.000000
# max    28.000000     3.250000

# %%
"""
statistical distribution:
 
|--catagory :normal probability distribution.
| |
| |--gaussian distributuion or a bell curve:
| |      it is the representation of a a large data set with various  variation into histo grams and line graphs.
| |      for eg, in a data collected for 100 individuals and their skill of
| |      basket ball. , most lies in the range of average skills , while the 
| |      people who never played basket ball and the people who  are exceptionally 
| |      good at basketball lies in the edges of it and are called 'outliners'
| |
| |
| |
| | ---00----00000000-0000-000000-000 ----00------0---
| |
| |                    +---+                       
| |                    |   |                       
| |                    |   |+---+                  
| |               +---+|   ||   |                  
| |               |   ||   ||   |                  
| |          +---+|   ||   ||   |                  
| |     +---+|   ||   ||   ||   |+---+             
| |     |   ||   ||   ||   ||   ||   |+---+        
| |     |   ||   ||   ||   ||   ||   ||   |   +---+   
| | ----+---++---++---++---++---++---++---+---+---+---
| |     0    5   10   15   20   25   30   35  40  45                 
| |
| |
| |  Kernal Density estimation:
| |  
| |  A histogram gives the frequency distribution of the probabilities that a value will come.
| |  it is also a bar graph. but based on discrete values.(for eg, if 14 comes thrice in the previous
| |  basketball abilities data out of 100 people who were interviewed, then graph will have a bar at
| |  14-15 of height =P(14) = 0.14 )
| |  since it is a representation of the probabiities, its total area under the curve=1 
"""
a=5

# %%
data2 = pd.concat([data, data, data, data, data, data, ], axis=0)
data2=data2.reset_index(drop=True)
print(data2)
# Out:
#    emp_id               name   location  age    home_at  spec_number
# 0   emp11       Aakash Kumar      Patna   22      Noida         0.00
# 1   emp12        Naman Arora    Lucknow   18      Delhi        -1.25
# 2   emp13         Vikas Jain     Bhopal   18    Gurgaon         1.00
# 3   emp14      Nirmal Mishra    Gurgaon   21    Gurgaon         2.00
# 4   emp15        Priya Singh    Gurgaon   25      Delhi        -1.75
# 5   cnt17  Rishab Srivastava     Mumbai   22      Noida         3.25
# 6   emp16      Pravita Singh     Kanpur   21      Delhi         0.00
# 7   tmp18        Naina Gupta    Sonipat   28  New Delhi         0.00
# 8   cnt19         Jai Tiwari  Hyderabad   24      Noida        -2.25
# 9   emp11       Aakash Kumar      Patna   22      Noida         0.00
# 10  emp12        Naman Arora    Lucknow   18      Delhi        -1.25
# 11  emp13         Vikas Jain     Bhopal   18    Gurgaon         1.00
# 12  emp14      Nirmal Mishra    Gurgaon   21    Gurgaon         2.00
# ...

# %%
#print(data2)
sns.distplot(data2['spec_number'])
"""
this function does many things

1)plotting the probabilities 
our data is:
    emp_id               name   location  age    home_at  spec_number
1   emp11       Aakash Kumar      Patna   22      Noida         0.00
2   emp12        Naman Arora    Lucknow   18      Delhi        -1.25
3   emp13         Vikas Jain     Bhopal   18    Gurgaon         1.00
4   emp14      Nirmal Mishra    Gurgaon   21    Gurgaon         2.00
5   emp15        Priya Singh    Gurgaon   25      Delhi        -1.75
6   cnt17  Rishab Srivastava     Mumbai   22      Noida         3.25
7   emp16      Pravita Singh     Kanpur   21      Delhi         0.00
8   tmp18        Naina Gupta    Sonipat   28  New Delhi         0.00
9   cnt19         Jai Tiwari  Hyderabad   24      Noida        -2.25

repeated over  times therefore , 54 entries.
for column , spec number , we can clearly see , 0-1(both included) has max entries  .i.e 4 /9
for 54 entries. p(0) =24/54


"""
x=8
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
f, ax = mplt.subplots(figsize=(10, 5))
sns.rugplot(data2['spec_number'],height=0.6,axis='x')
sns.distplot(data2['spec_number'], kde=False,rug=True )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(data2['spec_number'], kde=False,rug=True,bins=100 )

# %%
sns.distplot(data2['spec_number'], rug=True, hist=False, bins=40)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(color_codes=True)
sns.kdeplot(data2['spec_number'], shade=True,color='r')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
