# %%
from matplotlib import pyplot as plt
import numpy as np
import sys

print('versions:')
print('system:', sys.version)
print('numpy:', np.version)
# print('pypl0t:',plt.__version__)
# Out:
# versions:
# system: 3.6.6 |Anaconda custom (64-bit)| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
# numpy: <module 'numpy.version' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\version.py'>

# %%
# creating a figure: it will display nothing, not even empty space if you haven't added axis
fig = plt.figure(figsize=[5,5])
plt.show()

# %%
# adding axis
fig = plt.figure(figsize=[7,3])
axes = fig.add_axes([0, 0, 1, 1])
        # fig.add_axes([left,bottom,width,height] AND NOT [left,bottom,right,top])
print(type(fig),type(axes))
# Out:
# <class 'matplotlib.figure.Figure'> <class 'matplotlib.axes._axes.Axes'>

# %%
# the add axis function is typically weird. it kinda creates spaces for multiple graphs
# but why does each internal graph is marked from 0 to 1 only? why not 10,20,30,40 or something else?
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0.1, 0.1, 0.3, 0.3])
ax2 = fig.add_axes([0.5, 0.1, 0.3, 0.3])
ax3 = fig.add_axes([0.1, 0.5, 0.3, 0.3])
ax4 = fig.add_axes([0.5, 0.5, 0.3, 0.3])

# %%
# if we areange our graphs in a typical manner, we might not need the outer box
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.1, 0.3, 0.3])
ax2 = fig.add_axes([0.5, 0.1, 0.3, 0.3])
ax3 = fig.add_axes([0.1, 0.5, 0.3, 0.3])
ax4 = fig.add_axes([0.5, 0.5, 0.3, 0.3])

x = np.linspace(0, 6 * np.pi, 100)
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))
ax3.plot(x, np.tan(x))
ax4.plot(x, np.log10(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log10
#   if sys.path[0] == '':

# %%
# subplots
#Subplots is a derived class of axis which can perform the task of creating 
# multiple graphs more easily

fig = plt.figure(figsize=[8, 8])
ax = fig.add_axes([0, 0, 1, 1])
sub1=fig.add_subplot(221)
sub1.set_xlabel("sub1")

sub2=fig.add_subplot(222)
sub2.set_xlabel("sub2")

sub3=fig.add_subplot(223)
sub3.set_xlabel("sub3")

sub4=fig.add_subplot(224)
sub4.set_xlabel("sub4")

# the number 221 means a 2x2 grid in position 1, i.e top left
# Out:
# Text(0.5,0,'sub4')

# %%
# shortcut to create figure and subplot at the same time
fig, sub1 =plt.subplots()

# %%
# creating sub plots directly, without thinking about figure
x = np.linspace(0, 3 * np.pi, 100)

sub1 = plt.subplot2grid((2, 3), (0, 0))
sub1.set_xlabel('sub1')
sub1.plot(x, np.sin(x))

sub2 = plt.subplot2grid((2, 3), (0, 1))
sub2.set_xlabel('sub2')
sub2.plot(x, np.cos(x))

sub3 = plt.subplot2grid((2, 3), (0, 2),rowspan=2)
sub3.set_xlabel('sub3')
sub3.plot([2, 3, 4, 5], [8, 6, 4, 2])
sub3.yaxis.tick_right()

sub4 = plt.subplot2grid((2, 3), (1, 0),colspan=2)
sub4.set_xlabel('sub4')
sub4.plot(x,np.exp2(x))

# %%
# creating copyrighted plots
x = np.linspace(0, 6 * np.pi, 100)

fig, sub1 = plt.subplots()
sub1.set_xlabel('sub1')
sub1.plot(x, np.sin(x))
sub1.text(0,0,'COPYRIGHTED', color='blue', alpha=0.4, fontsize='30')

# sub2 = plt.subplot2grid((2, 3), (0, 1))
# sub2.set_xlabel('sub2')
# sub2.plot(x, np.cos(x))
# 
# sub3 = plt.subplot2grid((2, 3), (0, 2), rowspan=2)
# sub3.set_xlabel('sub3')
# sub3.plot([2, 3, 4, 5], [8, 6, 4, 2])
# sub3.yaxis.tick_right()
# 
# sub4 = plt.subplot2grid((2, 3), (1, 0), colspan=2)
# sub4.set_xlabel('sub4')
# sub4.plot(x, np.exp2(x))
# Out:
# Text(0,0,'COPYRIGHTED')

# %%
# creating copyrighted figures

x = np.linspace(0, 3 * np.pi, 100)

fig = plt.figure()
fig.text(0.5,0.5,'COPYRIGHTED', 
         color='blue',
         alpha=0.4,
         fontsize='30'
         )

sub1 = plt.subplot2grid((2, 3), (0, 0))
sub1.set_xlabel('sub1')
sub1.plot(x, np.sin(x))

sub2 = plt.subplot2grid((2, 3), (0, 1))
sub2.set_xlabel('sub2')
sub2.plot(x, np.cos(x))

sub3 = plt.subplot2grid((2, 3), (0, 2), rowspan=2)
sub3.set_xlabel('sub3')
sub3.plot([2, 3, 4, 5], [8, 6, 4, 2])
sub3.yaxis.tick_right()

sub4 = plt.subplot2grid((2, 3), (1, 0), colspan=2)
sub4.set_xlabel('sub4')
sub4.plot(x, np.exp2(x))

# %%
# setting image as watermark
import matplotlib.image as image

x = np.linspace(0, 6 * np.pi, 1000)
fig = plt.figure(figsize=[8, 8])
s1 = fig.add_subplot(331)

s1.plot([1, 2, 3, 4], [2, 4, 6, 8])
s1.plot(x, np.sin(x))
s1.plot(x, np.cos(x))

filename = r'C:\Users\anshs\00ANSH_PYTHON\MyPy\04-10-18 [1] NUMPY\IMAGE_PROCESSING and matplotlib\West_norm.png'
my_img = image.imread(filename)
fig.figimage(my_img, 0, 0, alpha=0.1, zorder=3)

# fig.figimage(matplot_image_obj,start_x,start_y,alpha,zorder)
# zorder is for the stacking position 
# zorder =1 means the object on the top
# zorder =5 means the object that is 5 levels below the top

# %%
# funtest
import matplotlib.pyplot as plt
import scipy as sp

# make Data array to draw in
M = sp.zeros((500,500))

dpi = 300.0

# create a frameless mpl figure
fig, axes = plt.subplots(figsize=(M.shape[0]/dpi,M.shape[1]/dpi),dpi=dpi)
axes.axis('off')
fig.subplots_adjust(bottom=0,top=1.0,left=0,right=1)
axes.matshow(M,cmap='gray')

# set custom font
import matplotlib.font_manager as fm
prop = fm.FontProperties()

# annotate something
axes.annotate('ABC',xy=(250,250),rotation=45,fontproperties=prop,color='white')

# get fig image data and read it back to numpy array
fig.canvas.draw()
w,h = fig.canvas.get_width_height()
Imvals = sp.fromstring(fig.canvas.tostring_rgb(),dtype='uint8')
ImArray = Imvals.reshape((w,h,3))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
