# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import scipy.stats as stats

print(np.version)
# Out:
# <module 'numpy.version' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\version.py'>

# %%
import statsmodels.api as sm

# %%
sunspots_data = sm.datasets.sunspots.load_pandas().data # loading a sample dataset
print(type(sunspots_data))
sunspots_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      YEAR  SUNACTIVITY
# 0  1700.0          5.0
# 1  1701.0         11.0
# 2  1702.0         16.0
# 3  1703.0         23.0
# 4  1704.0         36.0

# %%
sunspots_data.index = pd.Index(sm.tsa.datetools.dates_from_range('1700','2008'))
del sunspots_data['YEAR']
sunspots_data
# Out:
#             SUNACTIVITY
# 1700-12-31          5.0
# 1701-12-31         11.0
# 1702-12-31         16.0
# 1703-12-31         23.0
# 1704-12-31         36.0
# 1705-12-31         58.0
# 1706-12-31         29.0
# 1707-12-31         20.0
# 1708-12-31         10.0
# 1709-12-31          8.0
# 1710-12-31          3.0
# 1711-12-31          0.0
# 1712-12-31          0.0
# 1713-12-31          2.0
# 1714-12-31         11.0
# 1715-12-31         27.0
# 1716-12-31         47.0
# 1717-12-31         63.0
# 1718-12-31         60.0
# 1719-12-31         39.0
# 1720-12-31         28.0
# 1721-12-31         26.0
# 1722-12-31         22.0
# 1723-12-31         11.0
# 1724-12-31         21.0
# 1725-12-31         40.0
# 1726-12-31         78.0
# 1727-12-31        122.0
# 1728-12-31        103.0
# 1729-12-31         73.0
# ...                 ...
# 1979-12-31        155.4
# 1980-12-31        154.6
# 1981-12-31        140.4
# 1982-12-31        115.9
# 1983-12-31         66.6
# 1984-12-31         45.9
# ...

# %%
plt.figure(figsize=[13,6])
plt.plot(sunspots_data)
