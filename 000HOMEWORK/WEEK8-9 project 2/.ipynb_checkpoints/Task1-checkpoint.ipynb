# %% [markdown]
# # Project 2 Stack Overflow Survey (Matplotlib and Seaborn)
#
# Instructions -
# - Project work should be your own work, so any duplicacy in code/files will not be taken for evaluation
# - As part of this project the numbering of Question is very important. So while answering any question mention the Q. No.
# - Create a single code file in Jupyter Notebook (.ipynb) format
# - For answering any Descriptive Question, use the Markdown cell in Jupyter Notebook
# - Submit the project in a single zip file containing all your files/folders/data etc

# %% [markdown]
# ## Task1
#
# **As part of our second project we are going to work on Visualizations. Our task is to analyze the data, clean it, modify it as and when required and represent it in the form of graphs, charts, plots, which are more appealing to users.**
#
# **For this project we will be exploring data from Developers’ Survey done by stackoverflow.com every year. This data is huge consisting of around 1 lac developers’ world-wide and on multiple factors.**
#
# As part of this DataSet there are two files -
#
# survey_results_schema.csv – It contains list of all the columns and their description
# survey_results_public.csv – It contains the Survey data corresponding to different columns
#
# **Note – As Dataset is very big so use files carefully and as and when required slice and dice the data for easy handling.**

# %% [markdown]
# ### A)
#
# Import all the required Libraries

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#checking the versions
print(sns.__version__)  # 0.9.0
print(np.__version__)  # 1.15.3
print(pd.__version__)  # 0.23.4
# Out:
# 0.9.0
# 1.15.3
# 0.23.4

# %% [markdown]
# ### Task 1.B.
#
# B) Access the Dataset as pandas Dataframes:
# - df_schema – contains the data from the schema file
# - df_survey – contains the data for the survey

# %%
filename1= r'C:\Users\anshs\00ANSH_PYTHON\MyPy\000HOMEWORK\WEEK8-9 project 2\survey_results_public.csv'
filename2 = r'C:\Users\anshs\00ANSH_PYTHON\MyPy\000HOMEWORK\WEEK8-9 project 2\survey_results_schema.csv'

df_schema = pd.read_csv(filename2)
df_survey = pd.read_csv(filename1)

# %%
# getting stats about the 2 dataframes
df_survey.info(memory_usage='deep')
print("=======================")
df_schema.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Columns: 129 entries, Respondent to SurveyEasy
# dtypes: float64(41), int64(1), object(87)
# memory usage: 619.4 MB
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 2 columns):
# Column          129 non-null object
# QuestionText    129 non-null object
# dtypes: object(2)
# memory usage: 37.8 KB

# %% [markdown]
# ### Task 1.C)
#
# - Explore the df_schema to see what are different columns available and see their description.
# - Write 10 different columns which you find interesting in order to analyze the Developers’ Survey Data and support your answer by telling how these column can be used.
# - Your explanation can be in descriptive form or you can take a step ahead and think in terms of Visuals or even some Model.
# - (To answer this question, you can take separate column as well as combine multiple columns in order to make some understanding. Idea is to think how this data can be used to get some interesting facts about Developers)
#
#
# Ans.
# - I explored the df_schema below.
# - Since the dataset is huge and seems to focus around many aspects, I would like to narrow my analysis to the 'psycological nature of a developer' and thus, the  following columns:
#     1. Col name : WakeTime
#     Description : On days when you work, what time do you typically wake up?
#     Reason : Waketime is very important with respect to physical health of a body. It is a rumour that developers seems to work at night and sleep during the day. it would be interesting to find out if this is true with support of statistics.
#
#     2. Col name : HoursOutside
#     Description : On a typical day, how much time do you spend outside?
#     Reason : Because Society blames developers to be nerds and introverts. Can we prove them wrong?
#
#     3. Col name : SkipMeals
#     Description : In a typical week, how many times do you skip a meal in order to be more productive?
#     Reason : I felt interest in this because food habits are directly related to health of a person's body and people tend to forget about time or food, when engrossed in coding
#
#     4. Col name : Exercise
#     Description : In a typical week, how many times do you exercise?
#     Reason : Because Excersize is important for healthy body.
#
#     5. Col name : JobSatisfaction
#     Description : How satisfied are you with your current job? If you work more than one job, please answer regarding the one you spend the most hours on.
#     Reason : To find out how much people are satisfied with their current job(s) and why are they doing it if they aren't satisfied.
#
#     6. Col name : ConvertedSalary
#     Description : Salary converted to annual USD salaries using the exchange rate on 2018-01-18, assuming 12 working months and 50 working weeks.
#     Reason : This could be used with Jobsatisfaction to derive a graph depicting the effect of salaries on job satisfaction. Some people says that the more they earn, the lesser they feel satisfied by the job.
#
#     7. Col name : HoursComputer
#     Description : On a typical day, how much time do you spend on a desktop or laptop computer?
#     Reason : The same reason as waketime, i.e to know if developer really have a life outside their computer or not.
#
#     8. Col name : EthicsChoice
#     Description : Imagine that you were asked to write code for a purpose or product that you consider extremely unethical. Do you write the code anyway?
#     Reason : To analyse weather the developers really think before taking a project or just start anyway , as long as the project gives them money.
#
#     9. Col name : AgreeDisagree1
#     Description : To what extent do you agree or disagree with each of the following statements? I feel a sense of kinship or connection to other developers.
#     Reason : Developers is said to be the most friendliest job, as their is plenty to learn and share with everyone. it would be interesting to find the truth in this statement.
#
#     10. Col name : Gender
#     Reason : To find out if the tech industry is supportive of feminine gender or not.

# %% [markdown]
# Gender.
# Gender plays an important role in technological industry. It has been found that 92.29% of  Developers are male, with less than than 7 % of developers being female. the rest of the people being transgender , gender queer and other people giving multiple answers.
# Also, 34,385 people chose not to answer this question, which is arounf 34% of population , when considered. This shows the sensitivity of such question.

# %%
total_counts = len(df_survey) - 1

all_genders = df_survey.Gender.astype('str').value_counts()
# not_answered = (all_genders['nan'])
# del all_genders['nan']
# total_counts = (total_counts - not_answered)

print('total answres =', total_counts)
ax = all_genders.plot(kind='barh', figsize=(10, 6), color='#390084')
for i in ax.patches:
    ax.text(
        i.get_width(),
        i.get_y() + 0.3,
        str(round((i.get_width() / total_counts) * 100, 3)) + '% (' + str(i.get_width()) + ')',
        color='black'
    )

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#390084')
ax.spines['bottom'].set_color('#390084')

ax.legend()
ax.grid(which='major', linestyle='--', linewidth='0.5', color='#390084')

ax.set_title('Developer\'s  Gender Bar Graph.', fontsize=20)
ax.set_xlabel('No. of People.', fontsize=12)
ax.set_ylabel('Genders.', fontsize=12)
# Out:
# total answres = 98854
# Text(0, 0.5, 'Genders.')

# %% [markdown]
# ## Task 1.D
#
# D) Find out how many users took the survey and how many parameters have been stored corresponding to each user?
# (Data for each user is stored in a separate row)
# ( Hint - Check the number of rows and no. of columns.)

# %%
print('the number of users that took survey are :',len(df_survey))
print('total parameters for a particular user are:',len(df_survey.columns))
print('Actual parameters for each user are:')
for i in range(len(df_survey)):
               print('user:',i+1,'\tcolumns:',df_survey.iloc[i].notnull().sum() )
# Out:
# the number of users that took survey are : 98855
# total parameters for a particular user are: 129
# Actual parameters for each user are:
# user: 1 	columns: 111
# user: 2 	columns: 124
# user: 3 	columns: 17
# user: 4 	columns: 80
# user: 5 	columns: 120
# user: 6 	columns: 125
# user: 7 	columns: 125
# user: 8 	columns: 109
# user: 9 	columns: 125
# user: 10 	columns: 11
# user: 11 	columns: 15
# user: 12 	columns: 14
# user: 13 	columns: 15
# user: 14 	columns: 83
# user: 15 	columns: 112
# user: 16 	columns: 32
# user: 17 	columns: 52
# user: 18 	columns: 116
# user: 19 	columns: 64
# user: 20 	columns: 24
# user: 21 	columns: 125
# user: 22 	columns: 121
# user: 23 	columns: 111
# user: 24 	columns: 121
# user: 25 	columns: 79
# user: 26 	columns: 110
# user: 27 	columns: 118
# user: 28 	columns: 114
# user: 29 	columns: 38
# user: 30 	columns: 73
# user: 31 	columns: 126
# user: 32 	columns: 125
# user: 33 	columns: 111
# user: 34 	columns: 122
# user: 35 	columns: 77
# ...

# %% [markdown]
# ## Task 1.E
# E) Analyze the df_survey dataframe and see what kind of Data is available, its type, and its values for different users.
# Analyze 10 different columns from the Dataframe and write their
# Data Types,
# different values,
# most frequent values,
# min,
# max,
# average
# and explain how you can use it in your analysis (keeping the Data Type and values in mind).
# (Hint - In order to make any analysis the type of Data available is also taken into consideration and based on that
# we choose what type of analysis is possible.)

# %%
#1) analysis : following are the columns having values in a form whcih can be analysed statistically
#( i.e these have integral or float ata which can be checked for measures like min , max , average value , etc)
print(df_survey.describe().columns)
# Out:
# Index(['Respondent', 'AssessJob1', 'AssessJob2', 'AssessJob3', 'AssessJob4',
#        'AssessJob5', 'AssessJob6', 'AssessJob7', 'AssessJob8', 'AssessJob9',
#        'AssessJob10', 'AssessBenefits1', 'AssessBenefits2', 'AssessBenefits3',
#        'AssessBenefits4', 'AssessBenefits5', 'AssessBenefits6',
#        'AssessBenefits7', 'AssessBenefits8', 'AssessBenefits9',
#        'AssessBenefits10', 'AssessBenefits11', 'JobContactPriorities1',
#        'JobContactPriorities2', 'JobContactPriorities3',
#        'JobContactPriorities4', 'JobContactPriorities5', 'JobEmailPriorities1',
#        'JobEmailPriorities2', 'JobEmailPriorities3', 'JobEmailPriorities4',
#        'JobEmailPriorities5', 'JobEmailPriorities6', 'JobEmailPriorities7',
#        'ConvertedSalary', 'AdsPriorities1', 'AdsPriorities2', 'AdsPriorities3',
#        'AdsPriorities4', 'AdsPriorities5', 'AdsPriorities6', 'AdsPriorities7'],
#       dtype='object')

# %%
#2 The columns we choose

col1="AdsPriorities1"
des1="Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement is relevant to me"
res1="Shows how much an ad is important to developers"
print("colname:",col1)
print("Description:",des1)
print("Datatype:",df_survey[col1].dtype)
print("topmost 5 values:",df_survey[col1].head().tolist() )
print("most common value:", df_survey[col1].mode().tolist())
print("minimum value:", df_survey[col1].min())
print("maximum value:", df_survey[col1].max())
print("average value:", df_survey[col1].median())
print("Reason:",res1)
print("=================================================================================\n")

col2="AdsPriorities2"
des2="Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement is honest about its goals"
res2="Shows what people feel about the authenticity of ads"
print("colname:",col2)
print("Description:",des2)
print("Datatype:",df_survey[col2].dtype)
print("topmost 5 values:",df_survey[col2].head().tolist() )
print("most common value:", df_survey[col2].mode().tolist())
print("minimum value:", df_survey[col2].min())
print("maximum value:", df_survey[col2].max())
print("average value:", df_survey[col2].median())
print("Reason:",res2)
print("=================================================================================\n")


col3="AdsPriorities3"
des3="Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement provides useful information"
res3="shows how much people feel that they gain knowledge/ new info from ads"
print("colname:",col3)
print("Description:",des3)
print("Datatype:",df_survey[col3].dtype)
print("topmost 5 values:",df_survey[col3].head().tolist() )
print("most common value:", df_survey[col3].mode().tolist())
print("minimum value:", df_survey[col3].min())
print("maximum value:", df_survey[col3].max())
print("average value:", df_survey[col3].median())
print("Reason:",res3)
print("=================================================================================\n")


col4="AdsPriorities4"
des4="Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement seems trustworthy"
res4="shows if people really trust the sources shown in ads"
print("colname:",col4)
print("Description:",des4)
print("Datatype:",df_survey[col4].dtype)
print("topmost 5 values:",df_survey[col4].head().tolist() )
print("most common value:", df_survey[col4].mode().tolist())
print("minimum value:", df_survey[col4].min())
print("maximum value:", df_survey[col4].max())
print("average value:", df_survey[col4].median())
print("Reason:",res4)
print("=================================================================================\n")


col5="AdsPriorities5"
des5="Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement is from a company that I like"
res5="shows how ads are relevent to user"
print("colname:",col5)
print("Description:",des5)
print("Datatype:",df_survey[col5].dtype)
print("topmost 5 values:",df_survey[col5].head().tolist() )
print("most common value:", df_survey[col5].mode().tolist())
print("minimum value:", df_survey[col5].min())
print("maximum value:", df_survey[col5].max())
print("average value:", df_survey[col5].median())
print("Reason:",res5)
print("=================================================================================\n")


col6="AdsPriorities6"
des6="Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement offers something of value, like a free trial"
res6="shows if people find ads as irritating or rewarding"
print("colname:",col6)
print("Description:",des6)
print("Datatype:",df_survey[col6].dtype)
print("topmost 5 values:",df_survey[col6].head().tolist() )
print("most common value:", df_survey[col6].mode().tolist())
print("minimum value:", df_survey[col6].min())
print("maximum value:", df_survey[col6].max())
print("average value:", df_survey[col6].median())
print("Reason:",res6)
print("=================================================================================\n")


col7="AdsPriorities7"
des7="Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement avoids fluffy or vague language"
res7="shows if user finds the ads to hold acceptable content"
print("colname:",col7)
print("Description:",des7)
print("Datatype:",df_survey[col7].dtype)
print("topmost 5 values:",df_survey[col7].head().tolist() )
print("most common value:", df_survey[col7].mode().tolist())
print("minimum value:", df_survey[col7].min())
print("maximum value:", df_survey[col7].max())
print("average value:", df_survey[col7].median())
print("Reason:",res7)
print("=================================================================================\n")

col8="ConvertedSalary"
des8="Salary converted to annual USD salaries using the exchange rate on 2018-01-18, assuming 12 working months and 50 working weeks."
res8="can be used to find many statistical data like variation in salaries with repect to country,etc"
print("colname:",col8)
print("Description:",des8)
print("Datatype:",df_survey[col8].dtype)
print("topmost 5 values:",df_survey[col8].head().tolist() )
print("most common value:", df_survey[col8].mode().tolist())
print("minimum value:", df_survey[col8].min())
print("maximum value:", df_survey[col8].max())
print("average value:", df_survey[col8].median())
print("Reason:",res8)
print("=================================================================================\n")

col9="JobContactPriorities1"
des9="Imagine that a company wanted to contact you about a job that is a good fit for you. Please rank your preference in how you are contacted (by dragging the choices up and down), where 9 is the most preferred and 5 is the least preferred. Telephone call"
res9="Shows how much people are comfortable with phone calls as mode of Conversation for a job"
print("colname:",col9)
print("Description:",des9)
print("Datatype:",df_survey[col9].dtype)
print("topmost 5 values:",df_survey[col9].head().tolist() )
print("most common value:", df_survey[col9].mode().tolist())
print("minimum value:", df_survey[col9].min())
print("maximum value:", df_survey[col9].max())
print("average value:", df_survey[col9].median())
print("Reason:",res9)
print("=================================================================================\n")


col10="JobContactPriorities5"
des10="Imagine that a company wanted to contact you about a job that is a good fit for you. Please rank your preference in how you are contacted (by dragging the choices up and down), where 10 is the most preferred and 5 is the least preferred. Message on a social media site"
res10="Shows how much people are comfortable with social media as mode of Conversation for a job"
print("colname:",col10)
print("Description:",des10)
print("Datatype:",df_survey[col10].dtype)
print("topmost 5 values:",df_survey[col10].head().tolist() )
print("most common value:", df_survey[col10].mode().tolist())
print("minimum value:", df_survey[col10].min())
print("maximum value:", df_survey[col10].max())
print("average value:", df_survey[col10].median())
print("Reason:",res10)
print("=================================================================================\n")
# Out:
# colname: AdsPriorities1
# Description: Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement is relevant to me
# Datatype: float64
# topmost 5 values: [1.0, 3.0, nan, nan, 2.0]
# most common value: [1.0]
# minimum value: 1.0
# maximum value: 7.0
# average value: 2.0
# Reason: Shows how much an ad is important to developers
# ...
#
# colname: AdsPriorities2
# Description: Please rank the following advertising qualities in order of their importance to you (by dragging the choices up and down), where 1 is the most important, and 7 is the least important. The advertisement is honest about its goals
# Datatype: float64
# topmost 5 values: [5.0, 5.0, nan, nan, 3.0]
# most common value: [4.0]
# minimum value: 1.0
# maximum value: 7.0
# average value: 4.0
# Reason: Shows what people feel about the authenticity of ads
# ...
#
# colname: AdsPriorities3
# ...
